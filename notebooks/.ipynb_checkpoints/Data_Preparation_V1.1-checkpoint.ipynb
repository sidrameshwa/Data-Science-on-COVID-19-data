# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %matplotlib inline
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ![CRISP_DM](../reports/figures/CRISP_DM.png)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# * focus is always to understand the final data structure
# * support each step by visual analytics

# %% [markdown]
# ## Johns Hopkins GITHUB csv data

# %%
data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)

# %%
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  8/19/20  8/20/20  8/21/20  \
# 0        0        0        0        0  ...    37599    37856    37894
# 1        0        0        0        0  ...     7812     7967     8119
# 2        0        0        0        0  ...    39847    40258    40667
# 3        0        0        0        0  ...     1024     1024     1045
# 4        0        0        0        0  ...     2015     2044     2068
#
#    8/22/20  8/23/20  8/24/20  8/25/20  8/26/20  8/27/20  8/28/20
# 0    37953    37999    38054    38070    38113    38129    38140
# 1     8275     8427     8605     8759     8927     9083     9195
# 2    41068    41460    41858    42228    42619    43016    43403
# 3     1045     1045     1060     1060     1098     1098     1124
# 4     2134     2171     2222     2283     2332     2415     2471
#
# [5 rows x 224 columns]

# %%
time_idx=pd_raw.columns[4:]

# %%
df_plot = pd.DataFrame({
    'date':time_idx})
df_plot.head()
# Out:
#       date
# 0  1/22/20
# 1  1/23/20
# 2  1/24/20
# 3  1/25/20
# 4  1/26/20

# %%
pd_raw['Country/Region']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# 5                   Antigua and Barbuda
# 6                             Argentina
# 7                               Armenia
# 8                             Australia
# 9                             Australia
# 10                            Australia
# 11                            Australia
# 12                            Australia
# 13                            Australia
# 14                            Australia
# 15                            Australia
# 16                              Austria
# 17                           Azerbaijan
# 18                              Bahamas
# 19                              Bahrain
# 20                           Bangladesh
# 21                             Barbados
# 22                              Belarus
# 23                              Belgium
# 24                               Belize
# 25                                Benin
# 26                               Bhutan
# 27                              Bolivia
# 28               Bosnia and Herzegovina
# 29                             Botswana
# 30                               Brazil
# 31                               Brunei
# 32                             Bulgaria
# 33                         Burkina Faso
# 34                                Burma
# 35                              Burundi
# 36                           Cabo Verde
# 37                             Cambodia
# 38                             Cameroon
# 39                               Canada
# 40                               Canada
# 41                               Canada
# 42                               Canada
# 43                               Canada
# 44                               Canada
# 45                               Canada
# 46                               Canada
# 47                               Canada
# 48                               Canada
# 49                               Canada
# 50                               Canada
# 51                               Canada
# 52                               Canada
# 53             Central African Republic
# 54                                 Chad
# 55                                Chile
# 56                                China
# 57                                China
# 58                                China
# 59                                China
# 60                                China
# 61                                China
# 62                                China
# 63                                China
# 64                                China
# 65                                China
# 66                                China
# 67                                China
# 68                                China
# 69                                China
# 70                                China
# 71                                China
# 72                                China
# 73                                China
# 74                                China
# 75                                China
# 76                                China
# 77                                China
# 78                                China
# 79                                China
# 80                                China
# 81                                China
# 82                                China
# 83                                China
# 84                                China
# 85                                China
# 86                                China
# 87                                China
# 88                                China
# 89                             Colombia
# 90                              Comoros
# 91                  Congo (Brazzaville)
# 92                     Congo (Kinshasa)
# 93                           Costa Rica
# 94                        Cote d'Ivoire
# 95                              Croatia
# 96                                 Cuba
# 97                               Cyprus
# 98                              Czechia
# 99                              Denmark
# 100                             Denmark
# 101                             Denmark
# 102                    Diamond Princess
# 103                            Djibouti
# 104                            Dominica
# 105                  Dominican Republic
# 106                             Ecuador
# 107                               Egypt
# 108                         El Salvador
# 109                   Equatorial Guinea
# 110                             Eritrea
# 111                             Estonia
# 112                            Eswatini
# 113                            Ethiopia
# 114                                Fiji
# 115                             Finland
# 116                              France
# 117                              France
# 118                              France
# 119                              France
# 120                              France
# 121                              France
# 122                              France
# 123                              France
# 124                              France
# 125                              France
# 126                              France
# 127                               Gabon
# 128                              Gambia
# 129                             Georgia
# 130                             Germany
# 131                               Ghana
# 132                              Greece
# 133                             Grenada
# 134                           Guatemala
# 135                              Guinea
# 136                       Guinea-Bissau
# 137                              Guyana
# 138                               Haiti
# 139                            Holy See
# 140                            Honduras
# 141                             Hungary
# 142                             Iceland
# 143                               India
# 144                           Indonesia
# 145                                Iran
# 146                                Iraq
# 147                             Ireland
# 148                              Israel
# 149                               Italy
# 150                             Jamaica
# 151                               Japan
# 152                              Jordan
# 153                          Kazakhstan
# 154                               Kenya
# 155                        Korea, South
# 156                              Kosovo
# 157                              Kuwait
# 158                          Kyrgyzstan
# 159                                Laos
# 160                              Latvia
# 161                             Lebanon
# 162                             Lesotho
# 163                             Liberia
# 164                               Libya
# 165                       Liechtenstein
# 166                           Lithuania
# 167                          Luxembourg
# 168                          MS Zaandam
# 169                          Madagascar
# 170                              Malawi
# 171                            Malaysia
# 172                            Maldives
# 173                                Mali
# 174                               Malta
# 175                          Mauritania
# 176                           Mauritius
# 177                              Mexico
# 178                             Moldova
# 179                              Monaco
# 180                            Mongolia
# 181                          Montenegro
# 182                             Morocco
# 183                          Mozambique
# 184                             Namibia
# 185                               Nepal
# 186                         Netherlands
# 187                         Netherlands
# 188                         Netherlands
# 189                         Netherlands
# 190                         Netherlands
# 191                         New Zealand
# 192                           Nicaragua
# 193                               Niger
# 194                             Nigeria
# 195                     North Macedonia
# 196                              Norway
# 197                                Oman
# 198                            Pakistan
# 199                              Panama
# 200                    Papua New Guinea
# 201                            Paraguay
# 202                                Peru
# 203                         Philippines
# 204                              Poland
# 205                            Portugal
# 206                               Qatar
# 207                             Romania
# 208                              Russia
# 209                              Rwanda
# 210               Saint Kitts and Nevis
# 211                         Saint Lucia
# 212    Saint Vincent and the Grenadines
# 213                          San Marino
# 214               Sao Tome and Principe
# 215                        Saudi Arabia
# 216                             Senegal
# 217                              Serbia
# 218                          Seychelles
# 219                        Sierra Leone
# 220                           Singapore
# 221                            Slovakia
# 222                            Slovenia
# 223                             Somalia
# 224                        South Africa
# 225                         South Sudan
# 226                               Spain
# 227                           Sri Lanka
# 228                               Sudan
# 229                            Suriname
# 230                              Sweden
# 231                         Switzerland
# 232                               Syria
# 233                             Taiwan*
# 234                          Tajikistan
# 235                            Tanzania
# 236                            Thailand
# 237                         Timor-Leste
# 238                                Togo
# 239                 Trinidad and Tobago
# 240                             Tunisia
# 241                              Turkey
# 242                                  US
# 243                              Uganda
# 244                             Ukraine
# 245                United Arab Emirates
# 246                      United Kingdom
# 247                      United Kingdom
# 248                      United Kingdom
# 249                      United Kingdom
# 250                      United Kingdom
# 251                      United Kingdom
# 252                      United Kingdom
# 253                      United Kingdom
# 254                      United Kingdom
# 255                      United Kingdom
# 256                      United Kingdom
# 257                             Uruguay
# 258                          Uzbekistan
# 259                           Venezuela
# 260                             Vietnam
# 261                  West Bank and Gaza
# 262                      Western Sahara
# 263                               Yemen
# 264                              Zambia
# 265                            Zimbabwe
# Name: Country/Region, dtype: object

# %%
pd_raw[pd_raw['Country/Region']=='Germany'].iloc[:,4::].sum(axis=0)[0:4]
# Out:
# 1/22/20    0
# 1/23/20    0
# 1/24/20    0
# 1/25/20    0
# dtype: int64

# %%
country_list=['Italy',
              'US',
              'Spain',
              'Germany',
              'Korea, South',
              'Brazil',
              'Pakistan',
              'South Africa'
             ]

# %%
for each in country_list:
    df_plot[each]=np.array(pd_raw[pd_raw['Country/Region']==each].iloc[:,4::].sum(axis=0))

# %%
# %matplotlib inline
df_plot.set_index('date').plot()

# %% [markdown]
# ## Data Type Date

# %%
df_plot.head()
# Out:
#         date  Italy  US  Spain  Germany  Korea, South  Brazil  Pakistan  \
# 0 2020-01-22      0   1      0        0             1       0         0
# 1 2020-01-23      0   1      0        0             1       0         0
# 2 2020-01-24      0   2      0        0             2       0         0
# 3 2020-01-25      0   2      0        0             2       0         0
# 4 2020-01-26      0   5      0        0             3       0         0
#
#    South Africa
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
time_idx=[datetime.strptime( each,"%m/%d/%y") for each in df_plot.date] # convert to datetime
time_str=[each.strftime('%Y-%m-%d') for each in time_idx] # convert back to date ISO norm (str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-22be39898825> in <module>
# ----> 1 time_idx=[datetime.strptime( each,"%m/%d/%y") for each in df_plot.date] # convert to datetime
#       2 time_str=[each.strftime('%Y-%m-%d') for each in time_idx] # convert back to date ISO norm (str)
#
# <ipython-input-20-22be39898825> in <listcomp>(.0)
# ----> 1 time_idx=[datetime.strptime( each,"%m/%d/%y") for each in df_plot.date] # convert to datetime
#       2 time_str=[each.strftime('%Y-%m-%d') for each in time_idx] # convert back to date ISO norm (str)
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %%
df_plot['date']=time_idx
type(df_plot['date'][0])

# %%
df_plot.head()
# Out:
#         date  Italy  US  Spain  Germany  Korea, South  Brazil  Pakistan  \
# 0 2020-01-22      0   1      0        0             1       0         0
# 1 2020-01-23      0   1      0        0             1       0         0
# 2 2020-01-24      0   2      0        0             2       0         0
# 3 2020-01-25      0   2      0        0             2       0         0
# 4 2020-01-26      0   5      0        0             3       0         0
#
#    South Africa
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df_plot.to_csv('../data/processed/COVID_small_flat_table.csv',sep=';',index=False)

# %% [markdown]
# ## Relational data model - defining a primary key
#
# In the relational model of databases, a primary key is a specific choice of a minimal set of attributes (columns) that uniquely specify a tuple (row) in a relation (table) (source: wiki)
#
#
# A primary key’s main features are:
#
# * It must contain a unique value for each row of data.
# * It cannot contain null values.

# %%
data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)
pd_raw.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/15/20  4/16/20  4/17/20  4/18/20  \
# 0        0        0        0  ...      784      840      906      933
# 1        0        0        0  ...      494      518      539      548
# 2        0        0        0  ...     2160     2268     2418     2534
# 3        0        0        0  ...      673      673      696      704
# 4        0        0        0  ...       19       19       19       24
#
#    4/19/20  4/20/20  4/21/20  4/22/20  4/23/20  4/24/20
# 0      996     1026     1092     1176     1279     1351
# 1      562      584      609      634      663      678
# 2     2629     2718     2811     2910     3007     3127
# 3      713      717      717      723      723      731
# 4       24       24       24       25       25       25
#
# [5 rows x 98 columns]

# %%
pd_data_base=pd_raw.rename(columns={'Country/Region':'country',
                      'Province/State':'state'})
pd_data_base['state']=pd_data_base['state'].fillna('no')  #ensure a sring, important for indexing

# %%
pd_data_base=pd_data_base.drop(['Lat','Long'],axis=1)
pd_data_base.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    no  Afghanistan        0        0        0        0        0        0
# 1    no      Albania        0        0        0        0        0        0
# 2    no      Algeria        0        0        0        0        0        0
# 3    no      Andorra        0        0        0        0        0        0
# 4    no       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  4/15/20  4/16/20  4/17/20  4/18/20  4/19/20  \
# 0        0        0  ...      784      840      906      933      996
# 1        0        0  ...      494      518      539      548      562
# 2        0        0  ...     2160     2268     2418     2534     2629
# 3        0        0  ...      673      673      696      704      713
# 4        0        0  ...       19       19       19       24       24
#
#    4/20/20  4/21/20  4/22/20  4/23/20  4/24/20
# 0     1026     1092     1176     1279     1351
# 1      584      609      634      663      678
# 2     2718     2811     2910     3007     3127
# 3      717      717      723      723      731
# 4       24       24       25       25       25
#
# [5 rows x 96 columns]

# %%
pd_relational_model=pd_data_base.set_index(['state','country']) \
                                .T                              \
                                .stack(level=[0,1])             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model.head()
# Out:
#       date                         state         country  confirmed
# 0  1/22/20                       Alberta          Canada        0.0
# 1  1/22/20                      Anguilla  United Kingdom        0.0
# 2  1/22/20                         Anhui           China        1.0
# 3  1/22/20                         Aruba     Netherlands        0.0
# 4  1/22/20  Australian Capital Territory       Australia        0.0

# %%
pd_relational_model.dtypes
# Out:
# date          object
# state         object
# country       object
# confirmed    float64
# dtype: object

# %%
pd_relational_model['date']=pd_relational_model.date.astype('datetime64[ns]')

# %%
pd_relational_model.dtypes
# Out:
# date         datetime64[ns]
# state                object
# country              object
# confirmed           float64
# dtype: object

# %%
pd_relational_model.confirmed=pd_relational_model.confirmed.astype(int)

pd_relational_model.to_csv('../data/processed/COVID_relational_confirmed.csv',sep=';',index=False)

# %%
print(pd_relational_model[pd_relational_model['country']=='US'].tail())
# Out:
#             date state country  confirmed
# 23746 2020-04-20    no      US     784326
# 24010 2020-04-21    no      US     811865
# 24274 2020-04-22    no      US     840351
# 24538 2020-04-23    no      US     869170
# 24802 2020-04-24    no      US     905358

# %% [markdown]
# ## Attention due to the new structure of the Johns Hopkins data set the state information US is in a second file

# %%
data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
pd_raw_US=pd.read_csv(data_path)
pd_raw_US.head()
# Out:
#      UID iso2 iso3  code3  FIPS Admin2            Province_State  \
# 0   16.0   AS  ASM     16  60.0    NaN            American Samoa
# 1  316.0   GU  GUM    316  66.0    NaN                      Guam
# 2  580.0   MP  MNP    580  69.0    NaN  Northern Mariana Islands
# 3  630.0   PR  PRI    630  72.0    NaN               Puerto Rico
# 4  850.0   VI  VIR    850  78.0    NaN            Virgin Islands
#
#   Country_Region      Lat     Long_  ... 4/15/20  4/16/20  4/17/20  4/18/20  \
# 0             US -14.2710 -170.1320  ...       0        0        0        0
# 1             US  13.4443  144.7937  ...     135      135      136      136
# 2             US  15.0979  145.6739  ...      13       13       13       14
# 3             US  18.2208  -66.5901  ...     974     1043     1068     1118
# 4             US  18.3358  -64.8963  ...      51       51       51       53
#
#    4/19/20  4/20/20  4/21/20  4/22/20  4/23/20  4/24/20
# 0        0        0        0        0        0        0
# 1      136      136      136      136      139      141
# 2       14       14       14       14       14       14
# 3     1213     1252     1298     1252     1416     1276
# 4       53       53       53       54       54       54
#
# [5 rows x 105 columns]

# %%
# drop all non relevant fields! 
# Many of this fields do not belong to 
# a transactional data. These fields belong to so called master data
pd_raw_US=pd_raw_US.drop(['UID', 'iso2', 'iso3', 'code3', 'Country_Region','FIPS', 'Admin2',  'Lat', 'Long_', 'Combined_Key'],axis=1)
pd_data_base_US=pd_raw_US.rename(columns={'Province_State':'state'}).copy()

# %%
## the stack command has problems when only one information is available within a stacking level
pd_relational_model_US=pd_data_base_US.set_index(['state']) \
                                .T                              \
                                .stack()             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model_US['country']='US'
pd_relational_model_US['date']=[datetime.strptime( each,"%m/%d/%y") for each in pd_relational_model_US.date] # convert to datetime
pd_relational_model_US.head()
# Out:
#         date                     state  confirmed country
# 0 2020-01-22            American Samoa          0      US
# 1 2020-01-22                      Guam          0      US
# 2 2020-01-22  Northern Mariana Islands          0      US
# 3 2020-01-22               Puerto Rico          0      US
# 4 2020-01-22            Virgin Islands          0      US

# %%
# update the large relational file

# %%
pd_relational_model_all=pd_relational_model[pd_relational_model['country']!='US'].reset_index(drop=True)

# %%
pd_relational_model_all=pd.concat([pd_relational_model_all,pd_relational_model_US],ignore_index=True)

# %%
pd_relational_model_all.to_csv('../data/processed/20200424_COVID_relational_confirmed.csv',sep=';',index=False)

# %%
print(pd_relational_model_all[pd_relational_model_all['country']=='US'])
# Out:
#              date                     state country  confirmed
# 24722  2020-01-22            American Samoa      US          0
# 24723  2020-01-22                      Guam      US          0
# 24724  2020-01-22  Northern Mariana Islands      US          0
# 24725  2020-01-22               Puerto Rico      US          0
# 24726  2020-01-22            Virgin Islands      US          0
# ...           ...                       ...     ...        ...
# 331345 2020-04-24                      Utah      US          8
# 331346 2020-04-24                      Utah      US         81
# 331347 2020-04-24                      Utah      US          9
# 331348 2020-04-24                      Utah      US        140
# 331349 2020-04-24                      Utah      US          0
#
# [306628 rows x 4 columns]

# %% [markdown]
# ### cross check on full sum US data

# %%
check_US=pd_relational_model_all[pd_relational_model_all['country']=='US']

# %%
check_US[['date','country','confirmed']].groupby(['date','country']).sum()
# Out:
#                     confirmed
# date       country
# 2020-01-22 US               1
# 2020-01-23 US               1
# 2020-01-24 US               2
# 2020-01-25 US               2
# 2020-01-26 US               5
# 2020-01-27 US               5
# 2020-01-28 US               5
# 2020-01-29 US               5
# 2020-01-30 US               5
# 2020-01-31 US               7
# 2020-02-01 US               8
# 2020-02-02 US               8
# 2020-02-03 US              11
# 2020-02-04 US              11
# 2020-02-05 US              11
# 2020-02-06 US              11
# 2020-02-07 US              11
# 2020-02-08 US              11
# 2020-02-09 US              11
# 2020-02-10 US              11
# 2020-02-11 US              12
# 2020-02-12 US              12
# 2020-02-13 US              13
# 2020-02-14 US              13
# 2020-02-15 US              13
# 2020-02-16 US              13
# 2020-02-17 US              13
# 2020-02-18 US              13
# 2020-02-19 US              13
# 2020-02-20 US              13
# 2020-02-21 US              15
# 2020-02-22 US              15
# 2020-02-23 US              15
# 2020-02-24 US              15
# 2020-02-25 US              15
# 2020-02-26 US              15
# 2020-02-27 US              16
# 2020-02-28 US              16
# 2020-02-29 US              24
# 2020-03-01 US              30
# 2020-03-02 US              53
# 2020-03-03 US              73
# 2020-03-04 US             104
# 2020-03-05 US             172
# 2020-03-06 US             217
# 2020-03-07 US             336
# 2020-03-08 US             450
# 2020-03-09 US             514
# 2020-03-10 US             708
# 2020-03-11 US            1105
# 2020-03-12 US            1557
# 2020-03-13 US            2147
# 2020-03-14 US            2857
# 2020-03-15 US            2918
# 2020-03-16 US            4307
# 2020-03-17 US            6096
# 2020-03-18 US            8873
# 2020-03-19 US           14094
# 2020-03-20 US           19403
# 2020-03-21 US           25725
# 2020-03-22 US           33634
# 2020-03-23 US           43663
# 2020-03-24 US           53736
# 2020-03-25 US           65778
# 2020-03-26 US           83836
# 2020-03-27 US          101657
# 2020-03-28 US          121465
# 2020-03-29 US          140909
# 2020-03-30 US          161831
# 2020-03-31 US          188172
# 2020-04-01 US          213242
# 2020-04-02 US          243622
# 2020-04-03 US          275367
# 2020-04-04 US          308650
# 2020-04-05 US          336802
# 2020-04-06 US          366317
# 2020-04-07 US          397121
# 2020-04-08 US          428654
# 2020-04-09 US          462780
# 2020-04-10 US          496535
# 2020-04-11 US          526396
# 2020-04-12 US          555313
# 2020-04-13 US          580619
# 2020-04-14 US          607670
# 2020-04-15 US          636350
# 2020-04-16 US          667592
# 2020-04-17 US          699706
# 2020-04-18 US          732197
# 2020-04-19 US          758809
# 2020-04-20 US          784326
# 2020-04-21 US          811865
# 2020-04-22 US          840220
# 2020-04-23 US          869170
# 2020-04-24 US          905358
